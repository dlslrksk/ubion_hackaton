# %% [markdown]
# # VAR 코로나 전후 현황 분석

# %% [markdown]
# ## 주가 데이터 다운로드  및 탐색

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import statsmodels.api as sm
import FinanceDataReader as fdr
import matplotlib.pyplot as plt
import numpy as np
from pmdarima.arima import ndiffs
import pmdarima as pm


import warnings
warnings.filterwarnings("ignore")

# %%
#전처리 함수 
def preprocess_(path,  column_, slice='',  encoding=None, header='infer'):

    df = pd.read_csv(path, encoding=encoding, header=header)
    
    if slice:
        df = df[slice]

    df.columns = column_

    if (type(df.iloc[:,1][1])==str):
        df.iloc[:,1] = df.iloc[:,1].apply(lambda x: float(x.replace(',', '')))
        
    df['Date'] = df['Date'].str.replace('[^0-9]', '')
    df['Date'] = df['Date'].apply(lambda x: x[:4]+'-'+x[4:6]+'-'+x[6:])
    df['Date'] = pd.to_datetime(df['Date'])

    df.sort_values('Date', inplace=True)
    df.reset_index(inplace=True)
    df.drop(['index'], axis=1, inplace=True)

    return df

# %%
# 데이터 불러오기 
# df_krx = fdr.StockListing('KRX')
# df_krx
# df_krx[df_krx['Name']=='ks200'] #삼성전자 찾기 ['Symbol']
ksp = fdr.DataReader('KS200', '2020-1-19', '2022-3-19')

# %%
kspdf = pd.DataFrame(ksp['Close'])
kspdf.to_csv("kspdf.csv")

# %%
kspdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 534 entries, 2020-01-20 to 2022-03-18
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   534 non-null    float64
# dtypes: float64(1)
# memory usage: 8.3 KB

# %%
y_train = ksp['Close'][:int(0.8*len(ksp))] #이걸 학습시킨 다음에 
y_test = ksp['Close'][int(0.8*len(ksp)) : ] #이만큼을 아리마로 그어보겠다
y_train.plot()
y_test.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
SARIMAMonth = sm.tsa.statespace.SARIMAX(y_train, order=(0, 1, 0), seasonal_order=(1, 1, 0, 12) ,enforce_stationarity=False,enforce_invertibility=False)
SARIMA_results_month = SARIMAMonth.fit()
SARIMA_results_month.plot_diagnostics(figsize=(16, 8))
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98751D+00    |proj g|=  6.55671D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.557D-06   2.988D+00
#   F =   2.9875119599076827
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  This problem is unconstrained.

# %% [markdown]
# 오류 : Length of endogenous variable must be larger the the number of lags used in the model and the number of observations burned in the log-likelihood calculation.
#
# => enforce_stationarity=False 제거

# %% [markdown]
# ## ARIMA

# %%
y_train = kspdf.loc['2020-01-19':'2020-02-17']['Close']
y_test = kspdf.loc['2020-02-18':'2020-03-19']['Close'] #dataframe 형태가 아니라 int64 형태로 뽑아야 함 

plt.title('KS200 ARIMA')
plt.plot(y_train)
plt.plot(y_test)
plt.xticks(rotation=45)
# Out:
# (array([18283., 18293., 18300., 18307., 18314., 18322., 18329., 18336.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
#라이브러리 이용해 최적의 차분 차수 찾기 
kpss_diffs = ndiffs(y_train, alpha = 0.05, test= 'kpss', max_d = 6)
adf_diffs = ndiffs(y_train, alpha= 0.05, test= 'adf', max_d =6)
n_diffs = max(kpss_diffs,adf_diffs)

print(f'적정차분차수는 {n_diffs}')
# Out:
# 적정차분차수는 3

# %%
#파라미터 

#y값은 시계열 array 형태로 써야한다. 1:1 대응밖에 라이브러리 지원을 안한다. 
#차분차수 d는 위에서 나온 1값을 작성한다. 

model = pm.auto_arima(y=y_train,
            d = 3,
            start_p = 0,
            max_p = 10,
            start_q=0,
            max_q=5,
            seasonal = False,
            stepwise = True,
            trace =True)
            #삼성전자 주기가 반복적으로 보이지 않으니 계절성이 없다고 보고 seasonal = fasle 준다. 
            #stepwis는 옵티마이저의 역할을 한다. 
# pqr을 최적의 파라미터를 찾아준다. 그러니까 start 값을 주어 어디부터 찾기 시작할지를 정해준다. 
#max_P는 찾고 마지막으로 찾을 p값
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,3,0)(0,0,0)[0]             : AIC=122.117, Time=0.01 sec
#  ARIMA(1,3,0)(0,0,0)[0]             : AIC=117.228, Time=0.01 sec
#  ARIMA(0,3,1)(0,0,0)[0]             : AIC=inf, Time=0.03 sec
#  ARIMA(2,3,0)(0,0,0)[0]             : AIC=110.164, Time=0.01 sec
#  ARIMA(3,3,0)(0,0,0)[0]             : AIC=109.299, Time=0.01 sec
#  ARIMA(4,3,0)(0,0,0)[0]             : AIC=111.010, Time=0.02 sec
#  ARIMA(3,3,1)(0,0,0)[0]             : AIC=inf, Time=0.14 sec
#  ARIMA(2,3,1)(0,0,0)[0]             : AIC=inf, Time=0.02 sec
#  ARIMA(4,3,1)(0,0,0)[0]             : AIC=inf, Time=0.08 sec
#  ARIMA(3,3,0)(0,0,0)[0] intercept   : AIC=111.286, Time=0.02 sec
#
# Best model:  ARIMA(3,3,0)(0,0,0)[0]
# Total fit time: 0.363 seconds

# %%
#함수 제작 

def forcast_one_step():
    fc,conf_int = model.predict(n_periods=1, return_conf_int=True)
    #conf_int 는 신뢰구간이다. 양쪽 이 값 사이에 실제값이 존재할 수 있다.  
    return (fc.tolist()[0],np.asarray(conf_int).tolist()[0]) #리스트로 바꾼다음에 숫자만 뽑아내기 위해 [0]을 출력, ( ) 받은 두개의 인자를 튜플로 묶어서 출력   

#fc 은 예측값, 
# conf_int 은 신뢰구간

# %%
y_test
# Out:
# Date
# 2020-02-18    297.74
# 2020-02-19    298.33
# 2020-02-20    296.65
# 2020-02-21    292.42
# 2020-02-24    281.02
# 2020-02-25    284.24
# 2020-02-26    279.94
# 2020-02-27    277.09
# 2020-02-28    268.02
# 2020-03-02    270.37
# 2020-03-03    271.56
# 2020-03-04    278.13
# 2020-03-05    281.38
# 2020-03-06    275.10
# 2020-03-09    263.11
# 2020-03-10    264.67
# 2020-03-11    257.01
# 2020-03-12    247.62
# 2020-03-13    240.65
# 2020-03-16    232.97
# 2020-03-17    226.89
# 2020-03-18    215.83
# 2020-03-19    199.28
# Name: Close, dtype: float64

# %%
# y_test를 for문으로 계속 하나 받고 업데이트 하나 받고 업데이트 해서 점차적으로 예측할 수 있다. 
forcasst_list = []
y_pred = [] 
pred_upper = []
pred_lower = []

#for y_test를 for문으로 계속 하나 받고 업데이트 하나 받고 업데이트 해서 점차적으로 예측할 수 있다. 
for i in y_test:
    fc, conf = forcast_one_step()
    #튜플로 묶어도 각각으로 출력되나보다. 
    #최저값은 신뢰구간의 가장 작은 값, 최대값은 신뢰구간의 가장 큰 값 으로 잡아서 
    y_pred.append(fc)
    pred_upper.append(conf[1]) #최대 신뢰구간 81948.10571660382 ~ 업데이트 
    pred_lower.append(conf[0]) #최소 신뢰구간 77251.89428339618 ~ 업데이트 

    #계속 이 값을 넣고 업데이트하고 예측하고의 무한반복 
    model.update(i) #그래프로 그리기 위해 리스트로 만든다. 
    # print(model)

# %%
y_pred1 = pd.DataFrame({'test':y_test, 'pred':y_pred})
y_pred1
#어제 종가가 오늘 예측 종가가 된다. 최적의 파라미터로 0 1 0으로 찾았기 때문에 한스텝씩 받았기 때문에 전 종가를 오늘 종가로 반영했다.
# Out:
#               test        pred
# Date
# 2020-02-18  297.74  301.447762
# 2020-02-19  298.33  294.419224
# 2020-02-20  296.65  295.747611
# 2020-02-21  292.42  292.152677
# 2020-02-24  281.02  290.533079
# 2020-02-25  284.24  272.870907
# 2020-02-26  279.94  276.708035
# 2020-02-27  277.09  274.079237
# 2020-02-28  268.02  277.424619
# 2020-03-02  270.37  267.445970
# 2020-03-03  271.56  262.518721
# 2020-03-04  278.13  272.796290
# 2020-03-05  281.38  284.364892
# 2020-03-06  275.10  293.637492
# 2020-03-09  263.11  272.454198
# 2020-03-10  264.67  251.028008
# 2020-03-11  257.01  256.763734
# 2020-03-12  247.62  245.169146
# 2020-03-13  240.65  239.204539
# 2020-03-16  232.97  236.827161
# 2020-03-17  226.89  220.021998
# 2020-03-18  215.83  220.539463
# 2020-03-19  199.28  207.006078

# %%
print(model.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   42
# Model:               SARIMAX(3, 3, 0)   Log Likelihood                -128.581
# Date:                Sun, 01 May 2022   AIC                            265.161
# Time:                        20:12:07   BIC                            271.815
# Sample:                             0   HQIC                           267.549
#                                  - 42
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1659      0.186     -6.282      0.000      -1.530      -0.802
# ar.L2         -0.9548      0.186     -5.129      0.000      -1.320      -0.590
# ar.L3         -0.5161      0.129     -4.013      0.000      -0.768      -0.264
# sigma2        40.3999      9.065      4.457      0.000      22.634      58.166
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                 0.21
# Prob(Q):                              0.73   Prob(JB):                         0.90
# Heteroskedasticity (H):               1.40   Skew:                            -0.18
# Prob(H) (two-sided):                  0.56   Kurtosis:                         3.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ValueError: model.update(i) => could not convert string to float: 'Close'
#
# y_test 값에 close 가 포함되어있었음 왜?
# y_test가 dataframe 형태였기 때문 -> int64로 변경해줌

# %% [markdown]
# - ARIMA
#
# - 2020년 1월 19일 ~ 2월 17 (train)
# - 2020년 2월 18 ~ 3월 19일 (test)
# - 예측치 보고 실제 2월 18일 코스피 200과 비교해서 ARIMA가 얼마나 잘 되는지 확인.
# - 코로나가 아니었다면 2월 18일의 데이터는 어땠을까? --> 이 모델이 설명력 있는지 ARIMA 한계 관련 찾아보기

# %%
import plotly.graph_objects as go 
fig = go.Figure([
    go.Scatter(x=y_train.index, y=y_train, name='Train', mode='lines', line=dict(color='royalblue')),
    #테스트 데이터 
    go.Scatter(x=y_test.index, y=y_test, name='Test', mode='lines', line=dict(color='rgba(0,0,30,0.5)')),

    #pred data 
    go.Scatter(x=y_test.index, y=y_pred, name='pred', mode='lines', line=dict(color='red',dash='dot',width=3)),
])

fig.update_layout(height=400, width=1000, title_text="ARIMA 0,1,0")
fig.show()

# %% [markdown]
# ## VAR 해보기

# %% [markdown]
#  참고 : https://github.com/cheonbi/All-About-Time-Series-Analysis/blob/master/Lecture4_Algorithms_TimeSeries_Linear_Multivariate_KK.ipynb
#
#  https://sosoeasy.tistory.com/399

# %% [markdown]
# - 기간 2020 2. 18 ~ 2020. 7. 31 (train: test  = 8 : 2)
#
# - 변수
#     - KS200  - 파이넌스데이터리더
#     - 환율
#     - 유가 (WTI)
#     - VIX - 미국변동성지수
#     - 금

# %% [markdown]
# - 분석 순서
#
# 1. 데이터 전처리
# 2. 요약통계량 확인
# 3. 시계열 들의 stationary 체크, 확보
# 4. 변수들 간의 correlation 확인
# 5. VAR 분석
# 6. Granger Causality Test
# 7. 충격반응모형

# %% [markdown]
# ## 데이터 수집 및 전처리

# %%
#데이터 
kspdf = pd.read_csv("./kspdf.csv")
kspdf.set_index(kspdf['Date'], inplace=True)
kspdf.drop('Date', axis=1, inplace=True)
y_data= kspdf.loc['2020-02-18':'2020-07-31']
y_train = y_data[:int(0.7*len(y_data))]
y_test = y_data[int(0.7*len(y_data)):]

# %%
y_data
# Out:
#              Close
# Date
# 2020-02-18  297.74
# 2020-02-19  298.33
# 2020-02-20  296.65
# 2020-02-21  292.42
# 2020-02-24  281.02
# ...            ...
# 2020-07-27  293.51
# 2020-07-28  300.13
# 2020-07-29  301.25
# 2020-07-30  301.85
# 2020-07-31  299.32
#
# [115 rows x 1 columns]

# %%
y_train.describe()
# Out:
#             Close
# count   80.000000
# mean   257.682625
# std     22.313512
# min    199.280000
# 25%    245.425000
# 50%    255.645000
# 75%    273.667500
# max    298.330000

# %%
y_test.describe()
# Out:
#             Close
# count   35.000000
# mean   287.642286
# std      7.235454
# min    267.950000
# 25%    282.805000
# 50%    286.770000
# 75%    291.920000
# max    301.850000

# %%
#VIX 지수  'ZG'금 선물 (ICE) #'USD/KRW'달러/원화          
var_list = [['VIX',"VIX"],['USD/KRW','USD/KRW'],['gold','ZG']]
for name, code in var_list:
    globals()[f'Var_{name}'] = pd.DataFrame(fdr.DataReader(code, '2020-02-18', '2020-07-31')['Close']) #반복문으로 변수 생성 및 저장

# %%
globals()['Var_USD/KRW']
# Out:
#               Close
# Date
# 2020-02-18  1190.95
# 2020-02-19  1192.50
# 2020-02-20  1204.71
# 2020-02-21  1206.91
# 2020-02-24  1219.08
# ...             ...
# 2020-07-27  1195.57
# 2020-07-28  1199.46
# 2020-07-29  1189.79
# 2020-07-30  1189.62
# 2020-07-31  1193.59
#
# [119 rows x 1 columns]

# %%
# FRED 데이터
#소비자심리지수 (UMCSENT) #M2SL통화 유동량
FRED = fdr.DataReader(['M2SL','UMCSENT'],'2020-02-18','2020-07-31', data_source='fred') 
FRED
# Out:
#                M2SL  UMCSENT
# DATE
# 2020-02-01  15458.7    101.0
# 2020-03-01  15988.6     89.1
# 2020-04-01  17002.5     71.8
# 2020-05-01  17835.2     72.3
# 2020-06-01  18129.3     78.1
# 2020-07-01  18277.8     72.5

# %%
df_list = [y_data,globals()['Var_VIX'], globals()['Var_USD/KRW'], globals()['Var_gold'],FRED]

# %%
#concat( ) 활용해 결합 
dd = pd.concat(df_list, #objs속성은 리스트 형태로 데이터프레임을 묶어 
	axis = 1, # 0일 경우 행병합(위아래 합치기) 1일 경우 열병합(좌우로 합치기). Default는 0.
    	join = 'outer', # 'outer'의 경우 outer join, 'inner'의 경우 inner join. Optional.
        ignore_index = False, # True일 경우 기존의 index를 저장하지 않음. Default는 False.
        copy = False, # 복사
        verify_integrity = False # True일 경우 index가 중복되었는 지 확인
        )

# %%
dd
# Out:
#                       Close  Close    Close   Close     M2SL  UMCSENT
# 2020-02-01 00:00:00     NaN    NaN      NaN     NaN  15458.7    101.0
# 2020-02-18 00:00:00     NaN  14.83  1190.95  1657.9      NaN      NaN
# 2020-02-19 00:00:00     NaN  14.38  1192.50  1666.3      NaN      NaN
# 2020-02-20 00:00:00     NaN  15.56  1204.71  1674.8      NaN      NaN
# 2020-02-21 00:00:00     NaN  17.08  1206.91  1703.1      NaN      NaN
# ...                     ...    ...      ...     ...      ...      ...
# 2020-07-27           293.51    NaN      NaN     NaN      NaN      NaN
# 2020-07-28           300.13    NaN      NaN     NaN      NaN      NaN
# 2020-07-29           301.25    NaN      NaN     NaN      NaN      NaN
# 2020-07-30           301.85    NaN      NaN     NaN      NaN      NaN
# 2020-07-31           299.32    NaN      NaN     NaN      NaN      NaN
#
# [236 rows x 6 columns]

# %%
#컬럼명칭 변경 
dd.columns = ['KS200','VIX','USD/KRW','gold','M2SL','UMCSENT']
dd
# Out:
#                       KS200    VIX  USD/KRW    gold     M2SL  UMCSENT
# 2020-02-01 00:00:00     NaN    NaN      NaN     NaN  15458.7    101.0
# 2020-02-18 00:00:00     NaN  14.83  1190.95  1657.9      NaN      NaN
# 2020-02-19 00:00:00     NaN  14.38  1192.50  1666.3      NaN      NaN
# 2020-02-20 00:00:00     NaN  15.56  1204.71  1674.8      NaN      NaN
# 2020-02-21 00:00:00     NaN  17.08  1206.91  1703.1      NaN      NaN
# ...                     ...    ...      ...     ...      ...      ...
# 2020-07-27           293.51    NaN      NaN     NaN      NaN      NaN
# 2020-07-28           300.13    NaN      NaN     NaN      NaN      NaN
# 2020-07-29           301.25    NaN      NaN     NaN      NaN      NaN
# 2020-07-30           301.85    NaN      NaN     NaN      NaN      NaN
# 2020-07-31           299.32    NaN      NaN     NaN      NaN      NaN
#
# [236 rows x 6 columns]

# %%
dd.describe(include='all')
# Out:
#             KS200         VIX      USD/KRW         gold          M2SL  \
# count  115.000000  117.000000   119.000000    96.000000      6.000000
# mean   266.800783   36.607179  1213.847395  1763.616667  17115.350000
# std     23.502080   13.705481    17.107421    98.870569   1176.805722
# min    199.280000   14.380000  1180.500000  1511.800000  15458.700000
# 25%    252.010000   27.680000  1200.690000  1701.550000  16242.075000
# 50%    268.320000   32.610000  1212.460000  1759.300000  17418.850000
# 75%    286.210000   41.170000  1225.085000  1817.225000  18055.775000
# max    301.850000   82.690000  1272.500000  2034.400000  18277.800000
#
#          UMCSENT
# count    6.00000
# mean    80.80000
# std     11.88579
# min     71.80000
# 25%     72.35000
# 50%     75.30000
# 75%     86.35000
# max    101.00000

# %%
#결측치 확인
dd.gold.isnull().sum()
# Out:
# 140

# %%
#결측치는 전날 데이터로 채우기 
dd.fillna(method='pad',inplace=True)

# %%
#필요없는 구간 지우기 
dd = dd.loc['2020-02-18':'2020-07-31']
dd
# Out:
#              KS200    VIX  USD/KRW    gold     M2SL  UMCSENT
# 2020-02-18  297.74  24.46  1193.59  2034.4  18277.8     72.5
# 2020-02-19  298.33  24.46  1193.59  2034.4  18277.8     72.5
# 2020-02-20  296.65  24.46  1193.59  2034.4  18277.8     72.5
# 2020-02-21  292.42  24.46  1193.59  2034.4  18277.8     72.5
# 2020-02-24  281.02  24.46  1193.59  2034.4  18277.8     72.5
# ...            ...    ...      ...     ...      ...      ...
# 2020-07-27  293.51  24.46  1193.59  2034.4  18277.8     72.5
# 2020-07-28  300.13  24.46  1193.59  2034.4  18277.8     72.5
# 2020-07-29  301.25  24.46  1193.59  2034.4  18277.8     72.5
# 2020-07-30  301.85  24.46  1193.59  2034.4  18277.8     72.5
# 2020-07-31  299.32  24.46  1193.59  2034.4  18277.8     72.5
#
# [115 rows x 6 columns]

# %% [markdown]
# ## 데이터 탐색 시각화
# 참조 : https://dining-developer.tistory.com/30
# - https://dsbook.tistory.com/289?category=841791

# %%
dd.describe(include='all').T
# Out:
#          count          mean           std       min       25%       50%  \
# KS200    115.0    266.800783  2.350208e+01    199.28    252.01    268.32
# VIX      115.0     24.460000  0.000000e+00     24.46     24.46     24.46
# USD/KRW  115.0   1193.590000  2.283688e-13   1193.59   1193.59   1193.59
# gold     115.0   2034.400000  2.283688e-13   2034.40   2034.40   2034.40
# M2SL     115.0  18277.800000  3.653900e-12  18277.80  18277.80  18277.80
# UMCSENT  115.0     72.500000  0.000000e+00     72.50     72.50     72.50
#
#               75%       max
# KS200      286.21    301.85
# VIX         24.46     24.46
# USD/KRW   1193.59   1193.59
# gold      2034.40   2034.40
# M2SL     18277.80  18277.80
# UMCSENT     72.50     72.50

# %%
#데이터 시각화 
dd.plot(subplots=True, figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
dd.hist(bins=20, grid=True, figsize=(16,12))
# Out:
# array([[<AxesSubplot:title={'center':'KS200'}>,
#         <AxesSubplot:title={'center':'VIX'}>],
#        [<AxesSubplot:title={'center':'USD/KRW'}>,
#         <AxesSubplot:title={'center':'gold'}>],
#        [<AxesSubplot:title={'center':'M2SL'}>,
#         <AxesSubplot:title={'center':'UMCSENT'}>]], dtype=object)

# %% [markdown]
# 표준화가 필요한 데이터 로그가 필요한 데이터가 각각 존재
# 이미 정상성을 띠는 데이터도 다시 한번 취해줘도 되는건가?

# %%
dd.columns
# Out:
# Index(['KS200', 'VIX', 'USD/KRW', 'gold', 'M2SL', 'UMCSENT'], dtype='object')

# %%
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(data = dd.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(dd)

# %% [markdown]
# ## 데이터 모델 학습

# %%
# 필요 라이브러리 
import numpy as np
import matplotlib.pyplot as plt
import statsmodels
import statsmodels.api as sm

# %%
#로그 
dd_log = np.log1p(dd)

# %%
dd_log.hist(bins=20, grid=True, figsize=(16,12))
# Out:
# array([[<AxesSubplot:title={'center':'KS200'}>,
#         <AxesSubplot:title={'center':'VIX'}>],
#        [<AxesSubplot:title={'center':'USD/KRW'}>,
#         <AxesSubplot:title={'center':'gold'}>],
#        [<AxesSubplot:title={'center':'M2SL'}>,
#         <AxesSubplot:title={'center':'UMCSENT'}>]], dtype=object)

# %%
#차분을 이용한 추세제거 
dd_log.diff(1).dropna().plot(subplots=True, figsize=(12,8))
plt.tight_layout()
plt.show()

# %%
# #Standard sclaer 
# from sklearn.preprocessing import StandardScaler

# # 변형 객체 생성
# std_scaler = StandardScaler()

# # 훈련데이터의 모수 분포 저장
# std_scaler.fit(dd)

# # 훈련 데이터 스케일링
# dd= std_scaler.transform(dd)


# # 스케일링 된 결과 값으로 본래 값을 구할 수도 있다.
# # X_origin = std_scaler.inverse_transform(X_train_scaled)


#로그만 한게 나아서 그냥 로그만 진행

# %%
# VAR 모형적합
fit = sm.tsa.VAR(dd_log).fit(maxlags=3) #var2 모형 (2단위시간 전까지 값을 사용, Y_t=A1*Y_t-1+A2*Y_t-2+e_t, k=3)
display(fit.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/jeon-youseok/Desktop/ubion/ubion_hackaton/최종발표/Project_mini_re-main/var/VAR.ipynb Cell 57' in <module>
#       <a href='vscode-notebook-cell:/Users/jeon-youseok/Desktop/ubion/ubion_hackaton/%EC%B5%9C%EC%A2%85%EB%B0%9C%ED%91%9C/Project_mini_re-main/var/VAR.ipynb#ch0000056?line=0'>1</a> # VAR 모형적합
# ----> <a href='vscode-notebook-cell:/Users/jeon-youseok/Desktop/ubion/ubion_hackaton/%EC%B5%9C%EC%A2%85%EB%B0%9C%ED%91%9C/Project_mini_re-main/var/VAR.ipynb#ch0000056?line=1'>2</a> fit = sm.tsa.VAR(dd_log).fit(maxlags=3) #var2 모형 (2단위시간 전까지 값을 사용, Y_t=A1*Y_t-1+A2*Y_t-2+e_t, k=3)
#       <a href='vscode-notebook-cell:/Users/jeon-youseok/Desktop/ubion/ubion_hackaton/%EC%B5%9C%EC%A2%85%EB%B0%9C%ED%91%9C/Project_mini_re-main/var/VAR.ipynb#ch0000056?line=2'>3</a> display(fit.summary())
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py:696, in VAR.fit(self, maxlags, method, ic, trend, verbose)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=687'>688</a>     self.data.xnames = (
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=688'>689</a>         self.data.xnames[:k_trend]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=689'>690</a>         + x_names_to_add
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=690'>691</a>         + self.data.xnames[k_trend:]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=691'>692</a>     )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=692'>693</a> self.data.cov_names = pd.MultiIndex.from_product(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=693'>694</a>     (self.data.xnames, self.data.ynames)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=694'>695</a> )
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=695'>696</a> return self._estimate_var(lags, trend=trend)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py:717, in VAR._estimate_var(self, lags, offset, trend)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=714'>715</a> endog = self.endog[offset:]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=715'>716</a> exog = None if self.exog is None else self.exog[offset:]
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=716'>717</a> z = util.get_var_endog(endog, lags, trend=trend, has_constant="raise")
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=717'>718</a> if exog is not None:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=718'>719</a>     # TODO: currently only deterministic terms supported (exoglags==0)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=719'>720</a>     # and since exoglags==0, x will be an array of size 0.
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=720'>721</a>     x = util.get_var_endog(
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=721'>722</a>         exog[-nobs:], 0, trend="n", has_constant="raise"
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/var_model.py?line=722'>723</a>     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py:35, in get_var_endog(y, lags, trend, has_constant)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py?line=32'>33</a> trend = tsa.rename_trend(trend)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py?line=33'>34</a> if trend != 'n':
# ---> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py?line=34'>35</a>     Z = tsa.add_trend(Z, prepend=True, trend=trend,
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py?line=35'>36</a>                       has_constant=has_constant)
#      <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/vector_ar/util.py?line=37'>38</a> return Z
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py:152, in add_trend(x, trend, prepend, has_constant)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=146'>147</a>         base_err = (
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=147'>148</a>             "x contains one or more constant columns. Column(s) "
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=148'>149</a>             f"{const_cols} are constant."
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=149'>150</a>         )
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=150'>151</a>     msg = f"{base_err} Adding a constant with trend='{trend}' is not allowed."
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=151'>152</a>     raise ValueError(msg)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=152'>153</a> elif has_constant == "skip":
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/tsa/tsatools.py?line=153'>154</a>     columns = columns[1:]
#
# ValueError: x contains one or more constant columns. Column(s) 1, 2, 3, 4, 5, 7, 8, 9, 10, 11, 13, 14, 15, 16, 17 are constant. Adding a constant with trend='c' is not allowed.

# %%
#예측값 확인 
forecast_num = 20
# pred_var = fit.forecast(fit.model.endog[-1:], steps=forecast_num)
# pred_var_ci = fit.forecast_interval(fit.model.endog[-1:], steps=forecast_num)

fit.plot_forecast(forecast_num)
plt.tight_layout()
plt.show()

# %%
# 임펄스반응함수 추정
fit.irf(forecast_num).plot()
plt.tight_layout()
plt.show()

# %%
# 잔차진단
fit.plot_acorr()
plt.tight_layout()
plt.show()
