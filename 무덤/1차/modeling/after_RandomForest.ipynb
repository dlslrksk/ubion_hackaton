# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
import statsmodels.formula.api as sm
import warnings
warnings.filterwarnings('ignore')

# %%
# MinMax, Standard 함수

def minmax(data):
    scaled = MinMaxScaler().fit_transform(data)
    return scaled

def standard(data):
    scaled = StandardScaler().fit_transform(data)
    return scaled

def logscale(data):
    scaled = np.log1p(data)
    return scaled

# %%
after = pd.read_csv('../data_merge/after_data.csv')
after_data = after.drop(['Date','ETF'], axis=1)
after_target = after['ETF']
after
# Out:
#           Date    ETF     WTI  ExchangeRate   Gold    Pork     ITA
# 0   2021-11-01  10970   84.05        1177.5  67450  2393.0  105.36
# 1   2021-11-02  11175   83.91        1176.0  67760  2390.0  104.62
# 2   2021-11-03  11070   80.86        1183.5  67620  2376.0  105.46
# 3   2021-11-04  11000   78.81        1183.5  67400  2504.0  105.26
# 4   2021-11-05  10875   81.27        1184.5  68460  2515.0  108.96
# ..         ...    ...     ...           ...    ...     ...     ...
# 93  2022-03-25  14535  113.90        1221.0  76670  2402.0  112.95
# 94  2022-03-28  14470  105.96        1225.0  76380  2393.0  111.43
# 95  2022-03-29  14350  104.24        1211.0  75440  2389.0  112.02
# 96  2022-03-30  14020  107.82        1210.5  74810  2367.0  112.24
# 97  2022-03-31  14235  100.28        1214.5  75060  2370.0  110.79
#
# [98 rows x 7 columns]

# %%
## RandomForestRegressor
after = pd.read_csv('../data_merge/after_data.csv')
after_data = after.drop(['Date','ETF'], axis=1)
after_target = after['ETF']
after
x_train, x_test, y_train, y_test = train_test_split(after_data,after_target,
                                test_size=0.2,
                                random_state=42)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')
# Out:
# mse : 64861.715421900306
# rmse : 254.67963291535565
# r2 : 0.972293614384428

# %%
## RandomForestRegressor2
after = pd.read_csv('../data_merge/after_data.csv')
after_data = after.drop(['Date','ETF'], axis=1)
after_target = after['ETF']
after
x_train, x_test, y_train, y_test = train_test_split(after_data,after_target,
                                test_size=0.2,
                                random_state=42)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')
# Out:
# mse : 55699.728119315754
# rmse : 236.0078984257005
# r2 : 0.9762072566857334

# %%
## normal
after = pd.read_csv('../data_merge/after_data.csv')
after_data = after.drop(['Date','ETF'], axis=1)
after_target = after['ETF']
after

print("\nNO Scaler")
x_train, x_test, y_train, y_test = train_test_split(after_data, after_target,
                                test_size=0.2,
                                random_state=123)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')

## After MinMaxScaler
print("\nAfter MinMaxScaler")
x_train, x_test, y_train, y_test = train_test_split(after_data, after_target,
                                test_size=0.2,
                                random_state=123)

x_train_minmax = minmax(x_train)
x_test_minmax = minmax(x_test)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')

## After StandarScaler
print("\nAfter StandarScaler")
x_train, x_test, y_train, y_test = train_test_split(after_data, after_target,
                                test_size=0.2,
                                random_state=123)

x_train_standard = standard(x_train)
x_test_standard = standard(x_test)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')

## After log
print("\nAfter log")
x_train, x_test, y_train, y_test = train_test_split(after_data, after_target,
                                test_size=0.2,
                                random_state=123)

x_train_log = logscale(x_train)
x_test_log = logscale(x_test)

rf = RandomForestRegressor(n_estimators=400, max_depth=5)
rf.fit(x_train, y_train)
pred = rf.predict(x_test)
mse = mean_squared_error(y_test, pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, pred)
print(f'mse : {mse} \nrmse : {rmse} \nr2 : {r2}')
# Out:
# NO Scaler
# mse : 52957.01980293395
# rmse : 230.12392270890473
# r2 : 0.9745073076480683
#
# After MinMaxScaler
# mse : 55405.55707329046
# rmse : 235.3838504938061
# r2 : 0.973328619580316
#
# After StandarScaler
# mse : 59677.65659282381
# rmse : 244.2901074395437
# r2 : 0.9712720967783613
#
# After log
# mse : 55687.07833491146
# rmse : 235.98109741017703
# r2 : 0.9731930995880707

# %%
import scale_model_

# %%
a = scale_model_.complex(after_data, after_target)

# %%
a.Regression_(model='RandomForest', n_estimators=400, max_depth=3, scaler='logscale')
# Out:
# RandomForest\After logscale
# mse : 53357.04533488756
# rmse : 230.9914399602019
# r2 : 0.9743147415282799
