# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ###  before data 시각화

# %%
before = pd.read_csv('./data_merge/before_data.csv')
before_data = before.drop('ETF', axis=1)
before_target = before['ETF']
before
# Out:
#           Date    ETF    WTI  ExchangeRate   Gold    Pork     ITA
# 0   2020-11-02   8045  36.81        1135.5  68650  2062.0   77.44
# 1   2020-11-03   8120  37.66        1133.0  69010  2061.0   79.91
# 2   2020-11-04   8165  39.15        1140.0  69400  2039.0   79.87
# 3   2020-11-05   8335  38.79        1127.5  69250  2186.0   80.80
# 4   2020-11-06   8355  37.14        1122.5  69930  2181.0   80.73
# ..         ...    ...    ...           ...    ...     ...     ...
# 93  2021-03-25  10045  58.56        1136.1  63220  2124.0  102.28
# 94  2021-03-26   9985  60.97        1131.5  62770  2124.0  102.64
# 95  2021-03-29   9950  61.56        1133.5  62840  2151.0  103.18
# 96  2021-03-30   9880  60.55        1134.5  62110  2157.0  103.84
# 97  2021-03-31   9735  59.16        1129.5  61400  2163.0  104.11
#
# [98 rows x 7 columns]

# %%
#히트맵
before_withoutDate = before.drop(['Date'], axis=1)
corr_before = before_withoutDate.corr(method='pearson')
sns.heatmap(corr_before,annot=True, cmap='Blues')
#plt.savefig("heatmap")
# Out:
# <AxesSubplot:>

# %%
corr_before.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0c200_row0_col0, #T_0c200_row1_col1, #T_0c200_row2_col2, #T_0c200_row3_col3, #T_0c200_row4_col4, #T_0c200_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0c200_row0_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_0c200_row0_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_0c200_row0_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_0c200_row0_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0c200_row0_col5 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_0c200_row1_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_0c200_row1_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_0c200_row1_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0c200_row1_col4, #T_0c200_row3_col0, #T_0c200_row3_col1, #T_0c200_row3_col5, #T_0c200_row4_col2, #T_0c200_row5_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0c200_row1_col5 {
#   background-color: #084b93;
#   color: #f1f1f1;
# }
# #T_0c200_row2_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_0c200_row2_col1 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_0c200_row2_col3 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_0c200_row2_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_0c200_row2_col5 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_0c200_row3_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_0c200_row3_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_0c200_row4_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_0c200_row4_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0c200_row4_col3 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_0c200_row4_col5 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_0c200_row5_col0 {
#   background-color: #2272b6;
#   color: #f1f1f1;
# }
# #T_0c200_row5_col1 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_0c200_row5_col2 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_0c200_row5_col4 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# </style>
# <table id="T_0c200_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ETF</th>
#       <th class="col_heading level0 col1" >WTI</th>
#       <th class="col_heading level0 col2" >ExchangeRate</th>
#       <th class="col_heading level0 col3" >Gold</th>
#       <th class="col_heading level0 col4" >Pork</th>
#       <th class="col_heading level0 col5" >ITA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c200_level0_row0" class="row_heading level0 row0" >ETF</th>
#       <td id="T_0c200_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0c200_row0_col1" class="data row0 col1" >0.894912</td>
#       <td id="T_0c200_row0_col2" class="data row0 col2" >0.311532</td>
#       <td id="T_0c200_row0_col3" class="data row0 col3" >-0.525896</td>
#       <td id="T_0c200_row0_col4" class="data row0 col4" >-0.499268</td>
#       <td id="T_0c200_row0_col5" class="data row0 col5" >0.606871</td>
#     </tr>
#     <tr>
#       <th id="T_0c200_level0_row1" class="row_heading level0 row1" >WTI</th>
#       <td id="T_0c200_row1_col0" class="data row1 col0" >0.894912</td>
#       <td id="T_0c200_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0c200_row1_col2" class="data row1 col2" >0.412872</td>
#       <td id="T_0c200_row1_col3" class="data row1 col3" >-0.766633</td>
#       <td id="T_0c200_row1_col4" class="data row1 col4" >-0.533753</td>
#       <td id="T_0c200_row1_col5" class="data row1 col5" >0.808842</td>
#     </tr>
#     <tr>
#       <th id="T_0c200_level0_row2" class="row_heading level0 row2" >ExchangeRate</th>
#       <td id="T_0c200_row2_col0" class="data row2 col0" >0.311532</td>
#       <td id="T_0c200_row2_col1" class="data row2 col1" >0.412872</td>
#       <td id="T_0c200_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0c200_row2_col3" class="data row2 col3" >-0.302324</td>
#       <td id="T_0c200_row2_col4" class="data row2 col4" >-0.489026</td>
#       <td id="T_0c200_row2_col5" class="data row2 col5" >0.186880</td>
#     </tr>
#     <tr>
#       <th id="T_0c200_level0_row3" class="row_heading level0 row3" >Gold</th>
#       <td id="T_0c200_row3_col0" class="data row3 col0" >-0.525896</td>
#       <td id="T_0c200_row3_col1" class="data row3 col1" >-0.766633</td>
#       <td id="T_0c200_row3_col2" class="data row3 col2" >-0.302324</td>
#       <td id="T_0c200_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0c200_row3_col4" class="data row3 col4" >0.429766</td>
#       <td id="T_0c200_row3_col5" class="data row3 col5" >-0.835876</td>
#     </tr>
#     <tr>
#       <th id="T_0c200_level0_row4" class="row_heading level0 row4" >Pork</th>
#       <td id="T_0c200_row4_col0" class="data row4 col0" >-0.499268</td>
#       <td id="T_0c200_row4_col1" class="data row4 col1" >-0.533753</td>
#       <td id="T_0c200_row4_col2" class="data row4 col2" >-0.489026</td>
#       <td id="T_0c200_row4_col3" class="data row4 col3" >0.429766</td>
#       <td id="T_0c200_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_0c200_row4_col5" class="data row4 col5" >-0.206492</td>
#     </tr>
#     <tr>
#       <th id="T_0c200_level0_row5" class="row_heading level0 row5" >ITA</th>
#       <td id="T_0c200_row5_col0" class="data row5 col0" >0.606871</td>
#       <td id="T_0c200_row5_col1" class="data row5 col1" >0.808842</td>
#       <td id="T_0c200_row5_col2" class="data row5 col2" >0.186880</td>
#       <td id="T_0c200_row5_col3" class="data row5 col3" >-0.835876</td>
#       <td id="T_0c200_row5_col4" class="data row5 col4" >-0.206492</td>
#       <td id="T_0c200_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#산점도
#sns.pairplot(corr_before)
#plt.savefig("pairplot")

# %% [markdown]
# ### after data 시각화

# %%
after = pd.read_csv('./data_merge/after_data.csv')
after_data = after.drop('ETF', axis=1)
after_target = after['ETF']
after
# Out:
#           Date    ETF     WTI  ExchangeRate   Gold    Pork     ITA
# 0   2021-11-01  10970   84.05        1177.5  67450  2393.0  105.36
# 1   2021-11-02  11175   83.91        1176.0  67760  2390.0  104.62
# 2   2021-11-03  11070   80.86        1183.5  67620  2376.0  105.46
# 3   2021-11-04  11000   78.81        1183.5  67400  2504.0  105.26
# 4   2021-11-05  10875   81.27        1184.5  68460  2515.0  108.96
# ..         ...    ...     ...           ...    ...     ...     ...
# 93  2022-03-25  14535  113.90        1221.0  76670  2402.0  112.95
# 94  2022-03-28  14470  105.96        1225.0  76380  2393.0  111.43
# 95  2022-03-29  14350  104.24        1211.0  75440  2389.0  112.02
# 96  2022-03-30  14020  107.82        1210.5  74810  2367.0  112.24
# 97  2022-03-31  14235  100.28        1214.5  75060  2370.0  110.79
#
# [98 rows x 7 columns]

# %%
#히트맵
after_withoutDate = after.drop(['Date'], axis=1)
corr_after = after_withoutDate.corr(method='pearson')
sns.heatmap(corr_after,annot=True, cmap='Blues')
#plt.savefig("heatmap")
# Out:
# <AxesSubplot:>

# %%
corr_after.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_b77a0_row0_col0, #T_b77a0_row1_col1, #T_b77a0_row2_col2, #T_b77a0_row3_col3, #T_b77a0_row4_col4, #T_b77a0_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b77a0_row0_col1 {
#   background-color: #083c7d;
#   color: #f1f1f1;
# }
# #T_b77a0_row0_col2, #T_b77a0_row2_col0, #T_b77a0_row2_col3, #T_b77a0_row3_col2 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_b77a0_row0_col3, #T_b77a0_row3_col0 {
#   background-color: #083877;
#   color: #f1f1f1;
# }
# #T_b77a0_row0_col4 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b77a0_row0_col5 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_b77a0_row1_col0 {
#   background-color: #083d7f;
#   color: #f1f1f1;
# }
# #T_b77a0_row1_col2 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_b77a0_row1_col3 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_b77a0_row1_col4, #T_b77a0_row4_col0, #T_b77a0_row4_col1, #T_b77a0_row4_col2, #T_b77a0_row4_col3, #T_b77a0_row4_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b77a0_row1_col5 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_b77a0_row2_col1 {
#   background-color: #084e98;
#   color: #f1f1f1;
# }
# #T_b77a0_row2_col4 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b77a0_row2_col5 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b77a0_row3_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_b77a0_row3_col4 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b77a0_row3_col5, #T_b77a0_row5_col0 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_b77a0_row5_col1 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b77a0_row5_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_b77a0_row5_col3 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_b77a0_row5_col4 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# </style>
# <table id="T_b77a0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ETF</th>
#       <th class="col_heading level0 col1" >WTI</th>
#       <th class="col_heading level0 col2" >ExchangeRate</th>
#       <th class="col_heading level0 col3" >Gold</th>
#       <th class="col_heading level0 col4" >Pork</th>
#       <th class="col_heading level0 col5" >ITA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b77a0_level0_row0" class="row_heading level0 row0" >ETF</th>
#       <td id="T_b77a0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b77a0_row0_col1" class="data row0 col1" >0.918096</td>
#       <td id="T_b77a0_row0_col2" class="data row0 col2" >0.890339</td>
#       <td id="T_b77a0_row0_col3" class="data row0 col3" >0.948962</td>
#       <td id="T_b77a0_row0_col4" class="data row0 col4" >-0.565558</td>
#       <td id="T_b77a0_row0_col5" class="data row0 col5" >0.584968</td>
#     </tr>
#     <tr>
#       <th id="T_b77a0_level0_row1" class="row_heading level0 row1" >WTI</th>
#       <td id="T_b77a0_row1_col0" class="data row1 col0" >0.918096</td>
#       <td id="T_b77a0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b77a0_row1_col2" class="data row1 col2" >0.805438</td>
#       <td id="T_b77a0_row1_col3" class="data row1 col3" >0.895941</td>
#       <td id="T_b77a0_row1_col4" class="data row1 col4" >-0.704589</td>
#       <td id="T_b77a0_row1_col5" class="data row1 col5" >0.714778</td>
#     </tr>
#     <tr>
#       <th id="T_b77a0_level0_row2" class="row_heading level0 row2" >ExchangeRate</th>
#       <td id="T_b77a0_row2_col0" class="data row2 col0" >0.890339</td>
#       <td id="T_b77a0_row2_col1" class="data row2 col1" >0.805438</td>
#       <td id="T_b77a0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b77a0_row2_col3" class="data row2 col3" >0.893781</td>
#       <td id="T_b77a0_row2_col4" class="data row2 col4" >-0.571701</td>
#       <td id="T_b77a0_row2_col5" class="data row2 col5" >0.452273</td>
#     </tr>
#     <tr>
#       <th id="T_b77a0_level0_row3" class="row_heading level0 row3" >Gold</th>
#       <td id="T_b77a0_row3_col0" class="data row3 col0" >0.948962</td>
#       <td id="T_b77a0_row3_col1" class="data row3 col1" >0.895941</td>
#       <td id="T_b77a0_row3_col2" class="data row3 col2" >0.893781</td>
#       <td id="T_b77a0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b77a0_row3_col4" class="data row3 col4" >-0.590921</td>
#       <td id="T_b77a0_row3_col5" class="data row3 col5" >0.604335</td>
#     </tr>
#     <tr>
#       <th id="T_b77a0_level0_row4" class="row_heading level0 row4" >Pork</th>
#       <td id="T_b77a0_row4_col0" class="data row4 col0" >-0.565558</td>
#       <td id="T_b77a0_row4_col1" class="data row4 col1" >-0.704589</td>
#       <td id="T_b77a0_row4_col2" class="data row4 col2" >-0.571701</td>
#       <td id="T_b77a0_row4_col3" class="data row4 col3" >-0.590921</td>
#       <td id="T_b77a0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b77a0_row4_col5" class="data row4 col5" >-0.497159</td>
#     </tr>
#     <tr>
#       <th id="T_b77a0_level0_row5" class="row_heading level0 row5" >ITA</th>
#       <td id="T_b77a0_row5_col0" class="data row5 col0" >0.584968</td>
#       <td id="T_b77a0_row5_col1" class="data row5 col1" >0.714778</td>
#       <td id="T_b77a0_row5_col2" class="data row5 col2" >0.452273</td>
#       <td id="T_b77a0_row5_col3" class="data row5 col3" >0.604335</td>
#       <td id="T_b77a0_row5_col4" class="data row5 col4" >-0.497159</td>
#       <td id="T_b77a0_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 산점도
sns.pairplot(corr_after)
# plt.savefig("pairplot")
